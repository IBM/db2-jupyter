# %% [markdown]
# <h1>Db2 Magic Query into Pandas Data Frame</h1>

# %% [markdown]
# <p><strong>Welcome!</strong> This notebook will provide examples of using Db2 Magic Commands and converting the out put to a Pandas Data Frame.  Many of our data science examples use data in a Pandas data frame, so I thogut that this example would be useful since the magic commands put the output of a query into a LIST data type.</p>

# %% [markdown]
# <h2 id="dataset">About Db2 Magic Commands</h2>

# %% [markdown]
# Db2 Magic commands make it easy to run SQL in cells in your Jupyter Notebook as is without any Python code.  This notebook shows how to enable this feature in Cloud Pak for Data.  Using these examples would probably allow you to use them in Watson Studio outside of CPD as well.  I only show some basic Magic Commands here.  For more information on Db2 Magic Commands and lots of example see https://github.com/IBM/db2-jupyter/

# %% [markdown]
# <h2 id="pandas">Get the db2 magic commands notebook from github: <code>db2.ipynb</code></h2>

# %% [markdown]
# You must get and run the db2.iyndb notebook before using the magic commands.  You can't run the db2.ipynb notebook from the directory shown above.  Instead you need to reference the "raw" version as is done in the command below.  I got that raw URL by going into directory shown in the above "About" description, then clicking on the db2.ipynb link, and then clicking the "Raw" button near that top of the notebook itself.  Finally I copied the URL in the browser and pasted it in the wget command.

# %%
# !wget https://raw.githubusercontent.com/IBM/db2-jupyter/master/db2.ipynb
# Out:
# --2020-03-02 16:30:39--  https://raw.githubusercontent.com/IBM/db2-jupyter/master/db2.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 199.232.32.133
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|199.232.32.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 151979 (148K) [text/plain]
# Saving to: 'db2.ipynb.1'
#
# 100%[======================================>] 151,979     --.-K/s   in 0.03s
#
# 2020-03-02 16:30:39 (4.52 MB/s) - 'db2.ipynb.1' saved [151979/151979]

# %% [markdown]
# ### Run the db2 magic comands notebook

# %%
# %run db2.ipynb
# Out:
# Db2 Extensions Loaded.

# %% [markdown]
# ### Connect to Db2 Database
# Change the connect string to use your own database, user, password, host and port

# %%
# %sql CONNECT TO bludb USER user1013 USING ppppppp HOST host.or.ip PORT 50000;
# Out:
# Connection successful.

# %% [markdown]
# ##### Run a query, putting the output into a list called db2indexes_list
# Query the syscat.indexes view in the Db2 database.  Any view or table could be queried this way.  The magic command puts the data into a list datatype.  The row count, column count, data type and the view data are displayed.

# %%
db2indexs_list = %sql -r select * from syscat.indexes 
nbr_cols = len(db2indexs_list) - 1
print('ROW COUNT', len(db2indexs_list))
print('COLUMN COUNT',len(db2indexs_list[0]))
print(type(db2indexs_list))
print(db2indexs_list[0:3])
# Out:
# ROW COUNT 743
# COLUMN COUNT 72
# <class 'list'>
# ...

# %% [markdown]
# ##### Copy thge list to a data frame.

# %%
import pandas as pd
db2indexes_df = pd.DataFrame(db2indexs_list)
print(db2indexes_df.shape)
db2indexes_df.head()
# Out:
# (743, 72)
#           0            1         2          3          4          5   \
# 0  INDSCHEMA      INDNAME     OWNER  OWNERTYPE  TABSCHEMA    TABNAME
# 1   SYSIBM    INDTABLES01  SYSIBM            S   SYSIBM    SYSTABLES
# 2   SYSIBM    INDTABLES02  SYSIBM            S   SYSIBM    SYSTABLES
# 3   SYSIBM    INDTABLES03  SYSIBM            S   SYSIBM    SYSTABLES
# 4   SYSIBM    INDTABLES04  SYSIBM            S   SYSIBM    SYSTABLES
#
#                6           7            8         9                10  \
# 0        COLNAMES  UNIQUERULE  MADE_UNIQUE  COLCOUNT  UNIQUE_COLCOUNT
# 1   +CREATOR+NAME           U            N         2                2
# 2        +TBSPACE           D            N         1               -1
# 3  +INDEX_TBSPACE           D            N         1               -1
# 4   +LONG_TBSPACE           D            N         1               -1
#
#           11         12       13   14     15       16            17  \
# ...

# %% [markdown]
# ### You can have more complex queries if desired
# Also its always a good idea to get just the columns you need in your query and thus your data frame.  Use the back slash to continue the query on a new line.

# %%
db2indexs_list = %sql -r select indname, tabname, tabschema, uniquerule, colcount, \
                                pctfree, nlevels, stats_time, compression \
                           from syscat.indexes \
                          where TABSCHEMA not like 'SYS%' \
                            and TABSCHEMA not like 'IBM%' 
nbr_cols = len(db2indexs_list) - 1
print('ROW COUNT', len(db2indexs_list))
print('COLUMN COUNT',len(db2indexs_list[0]))
print(type(db2indexs_list))
db2indexes_df = pd.DataFrame(db2indexs_list)
print(db2indexes_df.shape)
db2indexes_df.head()
# Out:
# ROW COUNT 65
# COLUMN COUNT 9
# <class 'list'>
# (65, 9)
#                        0                                     1          2  \
# 0                INDNAME                               TABNAME  TABSCHEMA
# 1  SQL191215185042622707                 CUSTOMER_DEMOGRAPHICS   DFD
# 2  SQL191215185117765229                        CUSTOMER_CHURN   DFD
# 3  SQL191215185245683482  MERGED_DEMOGRAPHICS_TRADING_CUSTOMER   CPD
# 4  SQL191215185332076952               CUSTOMER_OFFER_ACCEPTED   CPD
#
#             3         4        5        6                           7  \
# 0  UNIQUERULE  COLCOUNT  PCTFREE  NLEVELS                  STATS_TIME
# 1           D         2        0        1  2019-12-15 18:50:46.545753
# 2           D         2        0        1  2019-12-15 18:51:20.166780
# 3           D         2        0        1  2019-12-15 18:52:48.293380
# 4           D         2        0        1  2019-12-15 18:53:35.401269
#
#              8
# 0  COMPRESSION
# 1            Y
# ...

# %% [markdown]
#  Disconnect from the database when you are done.

# %%
# %sql connect reset;
# Out:
# Connection successful.
